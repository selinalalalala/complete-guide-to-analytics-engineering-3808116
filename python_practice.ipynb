# %%
import pandas as pd

df = pd.read_csv('red_30_tech_us_sales.csv')

print(df.head())
# Out:
#          EmpID  OrderNum  OrderDate  OrderType  Quantity      Price  Discount  \
# 0  900015476.0   1100948   9/3/2017     Retail       1.0    $44.95         0
# 1  900015476.0   1101096  9/24/2017  Wholesale      10.0     $4.99     $1.00
# 2  900015476.0   1101138  10/1/2017  Wholesale       4.0   $250.00    $50.00
# 3  900015476.0   1101158  10/3/2017     Retail       1.0   $250.00         0
# 4  900015476.0   1101181  10/9/2017     Retail       1.0    $13.99         0
#
#   OrderTotal
# 0    $44.95
# 1    $48.90
# 2   $950.00
# 3   $250.00
# 4    $13.99
